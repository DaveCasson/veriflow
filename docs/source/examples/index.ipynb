# %% [markdown]
# # Tutorial Overview

# %% [markdown]
# |Title   	|Contents  	|Link 	|
# |---	|---	|---	|
# |01a - Basics   	|An example case-study comparing multiple models by running one integrated verification pipeline and interactively showing results. | [Notebook](1a_basics.ipynb)  	|
# |01b - Interpretation   	|A continuation of 1a, but with a focus on interpretation of results and custom Python plotting by making use of the `OutputDataset`.| [Notebook](1b_interpretation.ipynb)  	|
